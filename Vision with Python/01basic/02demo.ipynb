# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
im =array(Image.open('morvan1.jpg').convert('L'))

# %%
fig, axs = plt.subplots(1, 2)

# %%
plt.gray()

# %%
axs[0].contour(im,origin='image')

# %%
plt.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
plt.axis('off')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
axs[1].hist(im.flatten(),128)
plt.show()
